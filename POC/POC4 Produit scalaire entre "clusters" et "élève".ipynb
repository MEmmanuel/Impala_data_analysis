# %%
### Pour voir les métiers recommandés à un élève, on utilise la fonction show_score(eleve, n_metiers)
### --> eleve : liste des critères choisis par l'élève
### --> n_metiers : nombre de métiers à montrer

import io
import os
import json
import csv
import pandas as pd

# %%
### Préparation des chemins utiles
# Main directory
dir_path = '/home/timothee/PycharmProjects/ImpalaPoleEmploi2/Impala/POC'
# Dossier des données
data_dir_path = os.path.join(dir_path, 'Donnees')
# Métiers de chaque cluster :
jobs_clusters = os.path.join(data_dir_path, 'jobs_clusters.csv')
# Tableau des clusters-variables :
df_mean_file = os.path.join(data_dir_path, 'df_mean.csv')

# %%
# Chargement des données
df_mean = pd.read_csv(df_mean_file)
matrix_mean = df_mean.iloc[:,1:len(df_mean.columns)]

# %%
# Elèves fictifs avec les affinités qu'on pourrait imaginer(technicien, manager, artiste)
# On peut rajouter l'élève obtenu avec le POC "Choix des critères par l'utilisateur"
aude = ['Prendre des décisions, définir une stratégie',
 'Coordonner un projet, des actions, une formation',
 'Encadrer, gérer une équipe',
 'Gérer une production, une prestation de service',
 'Gérer un planning',
 'Gérer un budget, exécuter une tâche de gestion comptable, financière',
 'Organiser un évènement, superviser une opération',
 'Saisir et mettre en forme des documents',
 'Communiquer',
 'Traiter des images, des sons, des lumières, des contenus multimédias',
 'Actualiser des informations, des bases de données',
 'Synthétiser, traiter une information',
 'Concevoir une offre, un projet, un produit, un processus',
 'Enquêter, rechercher',
 'Elaborer une documentation technique',
 'Evaluer, étudier, analyser',
 'Artistique',
 'Mentales']

tim = ['Animer un groupe, une réunion (hors hiérarchie)',
 'Evaluer, étudier, analyser',
 'Concevoir une offre, un projet, un produit, un processus',
 'Enquêter, rechercher',
 'Encadrer, gérer une équipe',
 'Prendre des décisions, définir une stratégie',
 'Coordonner un projet, des actions, une formation',
 'Mathématiques/Statistiques',
 'Economie',
 'Sciences humaines et sociales',
 'Humaines (2)',
 'Humaines',
 'Résolution de problème',
 "Techniques d'entretien, Communication/Ecrit/oral",
 'Techniques pédagogiques',
 'Gestion de conflit',
 'Compétences managériales']

ines = ['Animer un groupe, une réunion (hors hiérarchie)',
 'Former une personne, enseigner',
 #'Proposer, vendre un produit, un service',
 'Evaluer, étudier, analyser',
 'Concevoir une offre, un projet, un produit, un processus',
 #'Décorer, agencer',
 #'Gérer une entreprise, un service',
 'Encadrer, gérer une équipe',
 #'Prendre des décisions, définir une stratégie',
 'Coordonner un projet, des actions, une formation',
 'Synthétiser, traiter une information',
 'Communiquer',
 'Organiser un évènement, superviser une opération',
 'Prendre soin de personnes',
 "Conseiller, donner un avis d'expert",
 'Identifier un besoin du client',
 'Artistique',
 #'Littérature, philosophie',
 "Communication / Traitement de l'information",
 'Gestion (2)',
 'Ressources Humaines',
 #'Marketing / Strategie',
 'Humaines',
 'Sciences humaines et sociales',
 'Humaines (2)',
 #'Image',
 #'Ecriture',
 'Compétences managériales',
 'Résolution de problème',
 'Techniques pédagogiques',
 'Gestion de conflit',
 'Légal']

yara = ['Communiquer',
 'Proposer, vendre un produit, un service',
 'Artistique',
 'Compétences managériales',
 'Marketing / Strategie']

hector = ['Faire un schéma, un plan, un dessin',
 'Enquêter, rechercher',
 'Encadrer, gérer une équipe',
 'Gérer une entreprise, un service',
 'Prendre des décisions, définir une stratégie',
 'Coordonner un projet, des actions, une formation',
 'Mentales']

jerome = ['Concevoir une offre, un projet, un produit, un processus',
 'Faire un schéma, un plan, un dessin',
 'Evaluer, étudier, analyser',
 'Enquêter, rechercher',
 'Cuisiner',
 'Produire, participer à des travaux manuels',
 "Prendre soin d'un animal",
 'Prendre soin de personnes',
 'Manipuler un outil, un appareil, un instrument',
 'Ranger, conditionner, trier',
 'Artistique',
 'Littérature, philosophie',
 'Linguistique',
 'Résolution de problème',
 'Gestion de conflit',
 'Matières naturelles',
 'Machines/outils/appareils',
 'Instruments de communication/multimédia',
 'Techniques',
 'Mentales']

eleve = ['Evaluer, étudier, analyser',
         'Enquêter, rechercher',
         'Littérature, philosophie',
         'Artistique',
         'Linguistique',
         "Techniques d'entretien, Communication/Ecrit/oral",
         'Résolution de problème',
         "Communication / Traitement de l'information",
         'Transport/Logistique']
manager = ["Conseiller, donner un avis d'expert",
            "Identifier un besoin du client",
            "Gérer un budget, exécuter une tâche de gestion comptable, financière",
           "Organiser un évènement, superviser une opération",
           "Coordonner un projet, des actions, une formation",
           "Encadrer, gérer une équipe",
           "Prendre des décisions, définir une stratégie",
           "Synthétiser, traiter une information",
           "Compétences managériales",
           "Résolution de problème",
           "Techniques d'entretien, Communication/Ecrit/oral",
           "Communication / Traitement de l'information",
           "Gestion, finance, comptabilité",
           "Mathématiques/Statistiques"]
technicien = ["Réaliser une activité de gros oeuvre (construire un batiment, une installation)",
                 "Réaliser une activité du second oeuvre (aménager, peindre, poser un revêtement)",
                 "Gérer une entreprise, un service",
                 "Conduire un véhicule, un engin",
                 "Conduire une machine",
                 "Manipuler un outil, un appareil, un instrument",
                 "Porter une charge par ses propres moyens",
                 "Effectuer des mesures",
                 "Diagnostiquer une panne",
                 "Réparer une machine, du matériel",
                 "Avec outil",
                 "Physiques",
                 "Techniques",
                 "Techniques, procédés de manutention",
                 "Gros oeuvre / Extraction",
                 "Machines/outils/appareils",
                 "Materiel et équipement",
                 "Engins/véhicules"]
artiste = ["Décorer, agencer",
          "Concevoir un projet artistique",
          "Jouer de la musique, chanter",
          "Jouer un rôle, défiler, danser",
          "Pratiquer un art plastique",
          "Faire un schéma, un plan, un dessin",
          "Communiquer",
          "Traiter des images, des sons, des lumières, des contenus multimédias",
          "Multimédia",
          "Artistique",
          "Littérature, philosophie"]

# %%
# Transforme les variables de la même manière que sur R
def cast_eleve_R(eleve_to_transform):
    eleve = []
    for feature in eleve_to_transform:
        feature = feature.replace(', ','..')
        feature = feature.replace('(', '.')
        feature = feature.replace(')', '.')
        feature = feature.replace("'", '.')
        feature = feature.replace("/", '.')
        feature = feature.replace(' ', '.')
        eleve.append(feature)
    return(eleve)

#### vecteur élève (petit problème à régler encore)
def vectorize_eleve(eleve_to_vectorize): 
    eleve = pd.DataFrame()
    for var in matrix_mean.columns.tolist():
        if var in eleve_to_vectorize:  
            eleve[var]=[1]
        else:
            eleve[var]=[0]
    return eleve

# Score obtenu par produit scalaire entre cluster et élève

def score_cluster(eleve):
    eleve_R = cast_eleve_R(eleve)
    eleve_v = vectorize_eleve(eleve_R)
    score = matrix_mean.dot(eleve_v.transpose())
    score.columns=["score"]
    score = score.sort_values(by="score",ascending=False)

    jobs_clust = pd.read_csv(jobs_clusters)
    final_scores = pd.DataFrame()
    for row in score.itertuples():
        k = row[0] + 1
        subset = jobs_clust[jobs_clust.clusters==k]
        subset = subset.loc[:,["intitule","clusters"]]
        subset["score"]= [row[1]]*len(subset)
        final_scores = final_scores.append(subset)
    return(final_scores)

def show_score(eleve, n_metiers=20):
    score_eleve = score_cluster(eleve)
    print("--> Préférences de l'élève : \n")
    for item in eleve:
        print(item)
    print("\n --> Métiers recommandés :")
    print(score_eleve[0:n_metiers])

# %%
show_score(aude, 20)
# Out:
# --> Préférences de l'élève :
#
# Prendre des décisions, définir une stratégie
# Coordonner un projet, des actions, une formation
# Encadrer, gérer une équipe
# Gérer une production, une prestation de service
# Gérer un planning
# Gérer un budget, exécuter une tâche de gestion comptable, financière
# Organiser un évènement, superviser une opération
# Saisir et mettre en forme des documents
# Communiquer
# Traiter des images, des sons, des lumières, des contenus multimédias
# Actualiser des informations, des bases de données
# Synthétiser, traiter une information
# Concevoir une offre, un projet, un produit, un processus
# Enquêter, rechercher
# Elaborer une documentation technique
# Evaluer, étudier, analyser
# Artistique
# Mentales
#
#  --> Métiers recommandés :
#                                               intitule  clusters      score
# 259  Encadrement d'équipe en industrie de transform...        73  20.122759
# 260  Encadrement d'équipe ou d'atelier en matériaux...        73  20.122759
# 118                   Journalisme et information média        40  13.653624
# 120                         Traduction, interprétariat        40  13.653624
# 130     Préparation et correction en édition et presse        40  13.653624
# 47                                            Stylisme        16  11.588580
# 137      Conception - aménagement d'espaces intérieurs        16  11.588580
# 209                                  Design industriel        16  11.588580
# 49    Conception - développement produits d'assurances        17  11.362427
# 53                   Études actuarielles en assurances        17  11.362427
# 62   Conception et expertise produits bancaires et ...        17  11.362427
# 463           Études et prospectives socio-économiques        17  11.362427
# 114                     Ecriture d'ouvrages, de livres        38  10.174522
# 115                                      Communication        38  10.174522
# 117                             Coordination d'édition        38  10.174522
# 384    Gestion de l'information et de la documentation        38  10.174522
# 431          Présentation de spectacles ou d'émissions        38  10.174522
# 502                       Direction de site logistique        98   6.761656
# 510   Direction d'escale et exploitation aéroportuaire        98   6.761656
# 514  Exploitation des opérations portuaires et du t...        98   6.761656

# %%
show_score(yara, 20)
# Out:
# --> Préférences de l'élève :
#
# Communiquer
# Proposer, vendre un produit, un service
# Artistique
# Compétences managériales
# Marketing / Strategie
#
#  --> Métiers recommandés :
#                                               intitule  clusters     score
# 81   Achat vente d'objets d'art, anciens ou d'occasion        30  9.210226
# 91               Vente en articles de sport et loisirs        30  9.210226
# 92          Vente en décoration et équipement du foyer        30  9.210226
# 94   Vente en habillement et accessoires de la pers...        30  9.210226
# 47                                            Stylisme        16  7.328825
# 137      Conception - aménagement d'espaces intérieurs        16  7.328825
# 209                                  Design industriel        16  7.328825
# 114                     Ecriture d'ouvrages, de livres        38  6.182298
# 115                                      Communication        38  6.182298
# 117                             Coordination d'édition        38  6.182298
# 384    Gestion de l'information et de la documentation        38  6.182298
# 431          Présentation de spectacles ou d'émissions        38  6.182298
# 96                               Assistanat commercial        34  4.126941
# 97   Relation commerciale grands comptes et entrepr...        34  4.126941
# 98         Relation commerciale auprès de particuliers        34  4.126941
# 99          Relation commerciale en vente de véhicules        34  4.126941
# 102                      Relation technico-commerciale        34  4.126941
# 376  Management de structure de santé, sociale ou p...        88  3.837797
# 459  Direction de grande entreprise ou d'établissem...        88  3.837797
# 460          Direction de petite ou moyenne entreprise        88  3.837797

# %%
show_score(hector, 20)
# Out:
# --> Préférences de l'élève :
#
# Faire un schéma, un plan, un dessin
# Enquêter, rechercher
# Encadrer, gérer une équipe
# Gérer une entreprise, un service
# Prendre des décisions, définir une stratégie
# Coordonner un projet, des actions, une formation
# Mentales
#
#  --> Métiers recommandés :
#                                               intitule  clusters      score
# 259  Encadrement d'équipe en industrie de transform...        73  17.916691
# 260  Encadrement d'équipe ou d'atelier en matériaux...        73  17.916691
# 187  Gestion de structure de loisirs ou d'hébergeme...        57  15.151053
# 511              Encadrement de la navigation maritime        57  15.151053
# 502                       Direction de site logistique        98   5.082308
# 510   Direction d'escale et exploitation aéroportuaire        98   5.082308
# 514  Exploitation des opérations portuaires et du t...        98   5.082308
# 515                  Exploitation du transport fluvial        98   5.082308
# 522  Direction d'exploitation des transports routie...        98   5.082308
# 523  Direction d'exploitation des transports routie...        98   5.082308
# 139                                         Dessin BTP        46   4.482159
# 140                                 Études géologiques        46   4.482159
# 142                             Mesures topographiques        46   4.482159
# 146  Direction et ingénierie d'exploitation de gise...        46   4.482159
# 491                           Information géographique        46   4.482159
# 492                         Information météorologique        46   4.482159
# 376  Management de structure de santé, sociale ou p...        88   4.301465
# 459  Direction de grande entreprise ou d'établissem...        88   4.301465
# 460          Direction de petite ou moyenne entreprise        88   4.301465
# 483                              Stratégie commerciale        88   4.301465

# %%
show_score(jerome, 20)
# Out:
# --> Préférences de l'élève :
#
# Concevoir une offre, un projet, un produit, un processus
# Faire un schéma, un plan, un dessin
# Evaluer, étudier, analyser
# Enquêter, rechercher
# Cuisiner
# Produire, participer à des travaux manuels
# Prendre soin d'un animal
# Prendre soin de personnes
# Manipuler un outil, un appareil, un instrument
# Ranger, conditionner, trier
# Artistique
# Littérature, philosophie
# Linguistique
# Résolution de problème
# Gestion de conflit
# Matières naturelles
# Machines/outils/appareils
# Instruments de communication/multimédia
# Techniques
# Mentales
#
#  --> Métiers recommandés :
#                                               intitule  clusters     score
# 30                         Création en arts plastiques        10  9.754544
# 166                    Taille et décoration de pierres        10  9.754544
# 237                     Réalisation de meubles en bois        10  9.754544
# 238          Réalisation d'ouvrages décoratifs en bois        10  9.754544
# 47                                            Stylisme        16  8.499521
# 137      Conception - aménagement d'espaces intérieurs        16  8.499521
# 209                                  Design industriel        16  8.499521
# 126                  Conduite de machines d'impression        45  7.292079
# 127          Conduite de machines de façonnage routage        45  7.292079
# 243  Conduite de machine de fabrication de produits...        45  7.292079
# 244  Conduite de machine de production et transform...        45  7.292079
# 245          Conduite de machine de textiles nontissés        45  7.292079
# 246          Conduite de machine de traitement textile        45  7.292079
# 253   Préparation de fils, montage de métiers textiles        45  7.292079
# 288  Conduite d'équipement de formage des plastique...        45  7.292079
# 430                     Mannequinat et pose artistique        92  7.090882
# 432                                              Danse        92  7.090882
# 433                                   Musique et chant        92  7.090882
# 434                                     Art dramatique        92  7.090882
# 435                     Arts du cirque et arts visuels        92  7.090882

# %%
show_score(eleve,20)
# Out:
# --> Préférences de l'élève :
#
# Evaluer, étudier, analyser
# Enquêter, rechercher
# Littérature, philosophie
# Artistique
# Linguistique
# Techniques d'entretien, Communication/Ecrit/oral
# Résolution de problème
# Communication / Traitement de l'information
# Transport/Logistique
#
#  --> Métiers recommandés :
#                                               intitule  clusters      score
# 114                     Ecriture d'ouvrages, de livres        38  10.294664
# 115                                      Communication        38  10.294664
# 117                             Coordination d'édition        38  10.294664
# 384    Gestion de l'information et de la documentation        38  10.294664
# 431          Présentation de spectacles ou d'émissions        38  10.294664
# 118                   Journalisme et information média        40   6.926659
# 120                         Traduction, interprétariat        40   6.926659
# 130     Préparation et correction en édition et presse        40   6.926659
# 21                Fermentation de boissons alcoolisées         8   5.694856
# 89                                   Vente de végétaux         8   5.694856
# 201              Management du service en restauration         8   5.694856
# 203                                        Sommellerie         8   5.694856
# 227  Intervention technique en formulation et analy...         8   5.694856
# 503   Intervention technique d'exploitation logistique        99   5.619867
# 507                 Contrôle de la navigation aérienne        99   5.619867
# 509                               Préparation des vols        99   5.619867
# 219  Management et ingénierie gestion industrielle ...        67   5.473517
# 220  Management et ingénierie méthodes et industria...        67   5.473517
# 221  Intervention technique en gestion industrielle...        67   5.473517
# 257             Management et ingénierie de production        67   5.473517

# %%
show_score(manager,20)
# Out:
# --> Préférences de l'élève :
#
# Conseiller, donner un avis d'expert
# Identifier un besoin du client
# Gérer un budget, exécuter une tâche de gestion comptable, financière
# Organiser un évènement, superviser une opération
# Coordonner un projet, des actions, une formation
# Encadrer, gérer une équipe
# Prendre des décisions, définir une stratégie
# Synthétiser, traiter une information
# Compétences managériales
# Résolution de problème
# Techniques d'entretien, Communication/Ecrit/oral
# Communication / Traitement de l'information
# Gestion, finance, comptabilité
# Mathématiques/Statistiques
#
#  --> Métiers recommandés :
#                                               intitule  clusters      score
# 259  Encadrement d'équipe en industrie de transform...        73  19.923607
# 260  Encadrement d'équipe ou d'atelier en matériaux...        73  19.923607
# 118                   Journalisme et information média        40  10.990202
# 120                         Traduction, interprétariat        40  10.990202
# 130     Préparation et correction en édition et presse        40  10.990202
# 114                     Ecriture d'ouvrages, de livres        38  10.201503
# 115                                      Communication        38  10.201503
# 117                             Coordination d'édition        38  10.201503
# 384    Gestion de l'information et de la documentation        38  10.201503
# 431          Présentation de spectacles ou d'émissions        38  10.201503
# 119                        Organisation d'évènementiel        41   7.772936
# 438              Promotion d'artistes et de spectacles        41   7.772936
# 52              Direction d'exploitation en assurances        19   7.254323
# 453         Audit et contrôle comptables et financiers        19   7.254323
# 454                                       Comptabilité        19   7.254323
# 456             Direction administrative et financière        19   7.254323
# 457       Management de groupe ou de service comptable        19   7.254323
# 101                       Management en force de vente        36   7.128732
# 103                           Téléconseil et télévente        36   7.128732
# 107        Direction de magasin de grande distribution        36   7.128732

# %%
show_score(technicien, 20)
# Out:
# --> Préférences de l'élève :
#
# Réaliser une activité de gros oeuvre (construire un batiment, une installation)
# Réaliser une activité du second oeuvre (aménager, peindre, poser un revêtement)
# Gérer une entreprise, un service
# Conduire un véhicule, un engin
# Conduire une machine
# Manipuler un outil, un appareil, un instrument
# Porter une charge par ses propres moyens
# Effectuer des mesures
# Diagnostiquer une panne
# Réparer une machine, du matériel
# Avec outil
# Physiques
# Techniques
# Techniques, procédés de manutention
# Gros oeuvre / Extraction
# Machines/outils/appareils
# Materiel et équipement
# Engins/véhicules
#
#  --> Métiers recommandés :
#                                               intitule  clusters      score
# 446                               Machinerie spectacle        94  22.751882
# 495                                       Déménagement        94  22.751882
# 517  Conduite de transport de marchandises sur long...        94  22.751882
# 521  Conduite et livraison par tournées sur courte ...        94  22.751882
# 150                      Extraction liquide et gazeuse        49  15.035310
# 151                                  Extraction solide        49  15.035310
# 164                Pose et restauration de couvertures        49  15.035310
# 168                              Construction en béton        49  15.035310
# 169                    Construction de routes et voies        49  15.035310
# 170                                         Maçonnerie        49  15.035310
# 171  Préparation du gros oeuvre et des travaux publics        49  15.035310
# 187  Gestion de structure de loisirs ou d'hébergeme...        57  12.725219
# 511              Encadrement de la navigation maritime        57  12.725219
# 449                                     Régie générale        95   9.004409
# 494       Conduite d'engins de déplacement des charges        95   9.004409
# 496             Magasinage et préparation de commandes        95   9.004409
# 516                              Manutention portuaire        95   9.004409
# 530                          Manoeuvre du réseau ferré        95   9.004409
# 319            Installation et maintenance en nautisme        81   8.885860
# 321  Maintenance d'engins de chantier, levage, manu...        81   8.885860

# %%
show_score(artiste, 20)
# Out:
# --> Préférences de l'élève :
#
# Décorer, agencer
# Concevoir un projet artistique
# Jouer de la musique, chanter
# Jouer un rôle, défiler, danser
# Pratiquer un art plastique
# Faire un schéma, un plan, un dessin
# Communiquer
# Traiter des images, des sons, des lumières, des contenus multimédias
# Multimédia
# Artistique
# Littérature, philosophie
#
#  --> Métiers recommandés :
#                                             intitule  clusters      score
# 436              Mise en scène de spectacles vivants        93  24.889350
# 439   Réalisation cinématographique et audiovisuelle        93  24.889350
# 430                   Mannequinat et pose artistique        92  19.074906
# 432                                            Danse        92  19.074906
# 433                                 Musique et chant        92  19.074906
# 434                                   Art dramatique        92  19.074906
# 435                   Arts du cirque et arts visuels        92  19.074906
# 121                                     Photographie        42  14.064937
# 122      Production en laboratoire cinématographique        42  14.064937
# 123         Production en laboratoire photographique        42  14.064937
# 447           Montage audiovisuel et post-production        42  14.064937
# 30                       Création en arts plastiques        10  11.053356
# 166                  Taille et décoration de pierres        10  11.053356
# 237                   Réalisation de meubles en bois        10  11.053356
# 238        Réalisation d'ouvrages décoratifs en bois        10  11.053356
# 114                   Ecriture d'ouvrages, de livres        38  10.113980
# 115                                    Communication        38  10.113980
# 117                           Coordination d'édition        38  10.113980
# 384  Gestion de l'information et de la documentation        38  10.113980
# 431        Présentation de spectacles ou d'émissions        38  10.113980
