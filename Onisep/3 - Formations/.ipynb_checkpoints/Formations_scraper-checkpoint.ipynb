# %%
# Ce script permet de scraper les formations de l'Onisep

import os
import json
import numpy as np
import math
import pandas as pd
from urllib import request
from bs4 import BeautifulSoup

# %%
# Chemins utiles
dir_path = '/home/timothee/PycharmProjects/ImpalaPoleEmploi2/Impala/Formations'
# Dossier data
data_dir_path = os.path.join(dir_path, 'data')
# Dossier output
output_dir_path = os.path.join(dir_path, 'output')
    
# Dossier output contenant les données et les fiches
formations_output_path = os.path.join(dir_path, 'output/formations.json')
errors_output_path = os.path.join(dir_path, 'output/errors.json')

# %%
# Liste des liens vers les formations (8095 formations)
formations_file_path = os.path.join(data_dir_path, 'Onisep_formation.csv')
df = pd.read_csv(formations_file_path, sep=";")
formations_links = df.iloc[:,[2,3,7]]

# %%
# Fonction qui récupère les onglets "Accès à la formation" et "Poursuivre mes études" 
# de la formation en lien et qui crée une fiche html 
def parse_formation_page(link):
    #print('GET '+ link)
    
    try:
        page = request.urlopen(link).read().decode('utf-8')

        page = page.replace('€', 'euros')  # because encode/decode error
        page = page.replace(u"\u2019", "'")  # because encode/decode error
        page = page.replace(u"\u2026", "é")  # because encode/decode error
        page = page.replace(u"\u0153", "oe")  # because encode/decode error

        page = page.replace('\n', '')  # remove new line
        page = page.replace('  ', '')  # remove big spaces (to be more human readable)
        #file = os.path.join(fiches_dir_path, name.replace('/', '-').replace(' ', '_') + '.html')
        #with open(file, 'w', encoding='utf8') as f:
        #    f.write(page)

        soup = BeautifulSoup(page, 'html.parser')

        formation = {}
        # Onglet "Débouchés professionnels"
        onglet = soup.find(name='div', attrs={'id': 'oni_onglet-1'})
        if onglet is not None:
            onglet_name = onglet.h2.extract().get_text()
            if onglet_name=="Débouchés professionnels":
                formation[onglet_name] = {}
                formation[onglet_name]["Débouchés"] = []
                formation[onglet_name]["Exemples de métiers"] = []
                for element in onglet.find_all():
                    #print(element)
                    if element.name=='p' and element.get_text() not in ["Exemple(s) de métier(s):"]:
                        formation[onglet_name]["Débouchés"].append(element.get_text())
                    if element.name=='li':
                        formation[onglet_name]["Exemples de métiers"].append(element.get_text())
                        #print(element)
                        
        # Onglet "Accès à la formation"
        onglet = soup.find(name='div', attrs={'id': 'oni_onglet-2'})
        if onglet is not None:
            onglet_name = onglet.h2.extract().get_text()
            if onglet_name=="Accès à la formation ":
                formation[onglet_name]={}
                formation[onglet_name]["Accès"] = []
                formation[onglet_name]["Exemples de formations requises"] = []
                for element in onglet.find_all():
                    #print(element)
                    if element.name=='p' and element.get_text() not in ["Admission","Exemples de formations requises:"]:
                        formation[onglet_name]["Accès"].append(element.get_text())
                    if element.name=='li' and element.find(name='a')==None:
                        formation[onglet_name]["Accès"].append(element.get_text())
                    if element.name=='li' and element.find(name='a')!=None:
                        formation[onglet_name]["Exemples de formations requises"].append(element.get_text())

                            
        # Onglet "Poursuivre mes études"
        onglet = soup.find(name='div', attrs={'id': 'oni_onglet-3'})
        if onglet is not None:
            onglet_name = onglet.h2.extract().get_text()
            if onglet_name=="Poursuivre mes études...":
                formation[onglet_name]={}
                formation[onglet_name]["Poursuivre"] = []
                formation[onglet_name]["Exemples de formations poursuivies"] = []
                for element in onglet.find_all():
                    if element.name=='li':
                        formation[onglet_name]["Exemples de formations poursuivies"].append(element.get_text())
                    if element.name=='p' and element.get_text() not in ["Poursuite d'études conditionnelle"]:
                        formation[onglet_name]["Poursuivre"].append(element.get_text().strip())
                        
        return formation
    
    except:
        return('error')

#formation = parse_formation_page("http://www.onisep.fr/Ressources/Univers-Formation/Formations/Post-bac/BTS-Maintenance-des-systemes-electro-navals")
#formation

# %%
def get_name_formation(link):
    try:
        page = request.urlopen(link).read().decode('utf-8')

        page = page.replace('€', 'euros')  # because encode/decode error
        page = page.replace(u"\u2019", "'")  # because encode/decode error
        page = page.replace(u"\u2026", "é")  # because encode/decode error
        page = page.replace(u"\u0153", "oe")  # because encode/decode error

        page = page.replace('\n', '')  # remove new line
        page = page.replace('  ', '')  # remove big spaces (to be more human readable)
        #file = os.path.join(fiches_dir_path, name.replace('/', '-').replace(' ', '_') + '.html')
        #with open(file, 'w', encoding='utf8') as f:
        #    f.write(page)

        soup = BeautifulSoup(page, 'html.parser')
        
        bloc = soup.find(name='h1')
        return(bloc.get_text())

    except:
        return('error')
        
#name = get_name_formation('http://www.onisep.fr/Ressources/Univers-Formation/Formations/Post-bac/BTS-Management-des-unites-commerciales')
#name

# %%
# Fonction pour récupérer les formations des lignes i à j dans le document formations.csv de l'Onisep
# La liste "errors" contient les formations avec des liens inexistants
def get_formations(i,j):
    formations_links_i_j = formations_links.iloc[i:j,:]
    formations = {}
    errors = []
    for row in formations_links_i_j.iterrows():
        #name = row[1]["libellé principal"]
        #if str(row[1]["libellé complémentaire"])!='nan':
        #    name = name + ' : ' + str(row[1]["libellé complémentaire"])
        link = row[1]["lien site onisep.fr"]
        name = get_name_formation(link)
        formation_content = parse_formation_page(link)
        if formation_content is not 'error':
            formations[name] = formation_content
        else:
            if name is not 'error':
                errors.append(name)
            else:
                name = row[1]["libellé principal"]
                if str(row[1]["libellé complémentaire"])!='nan':
                    name = name + ' : ' + str(row[1]["libellé complémentaire"])
                    
    # Copie du dictionnaire au format JSON
    formations_output_path = os.path.join(dir_path, 'output/formations_' + str(i) + '_' + str(j) + '.json')
    with open(formations_output_path, 'w') as f:
        json.dump(formations, f, indent=4)

    # Copie du dictionnaire au format JSON
    errors_output_path = os.path.join(dir_path, 'output/errors_' + str(i) + '_' + str(j) + '.json')
    with open(errors_output_path, 'w') as f:
        json.dump(errors, f, indent=4)

# %%
get_formations(25,28)

# %%
get_formations(0,1000)

# %%
get_formations(1000,2000)

# %%
get_formations(2000,3000)

# %%
get_formations(3000,4000)

# %%
get_formations(4000,5000)

# %%
get_formations(5000,6000)

# %%
get_formations(6000,7000)

# %%
get_formations(7000,8000)

# %%
get_formations(8000,8096)

# %%
file1 = os.path.join(dir_path,'output/formations_' + str(0) + '_' + str(1000) + '.json') 
file2 = os.path.join(dir_path,'output/formations_' + str(1000) + '_' + str(2000) + '.json') 
file3 = os.path.join(dir_path,'output/formations_' + str(2000) + '_' + str(3000) + '.json') 
file4 = os.path.join(dir_path,'output/formations_' + str(3000) + '_' + str(4000) + '.json') 
file5 = os.path.join(dir_path,'output/formations_' + str(4000) + '_' + str(5000) + '.json') 
file6 = os.path.join(dir_path,'output/formations_' + str(5000) + '_' + str(6000) + '.json') 
file7 = os.path.join(dir_path,'output/formations_' + str(6000) + '_' + str(7000) + '.json') 
file8 = os.path.join(dir_path,'output/formations_' + str(7000) + '_' + str(8000) + '.json') 
file9 = os.path.join(dir_path,'output/formations_' + str(8000) + '_' + str(8096) + '.json') 


with open(file1, 'r') as f:
    f1 = json.load(f)

with open(file2, 'r') as f:
    f2 = json.load(f)

with open(file3, 'r') as f:
    f3 = json.load(f)

with open(file4, 'r') as f:
    f4 = json.load(f)
    
with open(file5, 'r') as f:
    f5 = json.load(f)
    
with open(file6, 'r') as f:
    f6 = json.load(f)
    
with open(file7, 'r') as f:
    f7 = json.load(f)
    
with open(file8, 'r') as f:
    f8 = json.load(f)

with open(file9, 'r') as f:
    f9 = json.load(f)
print(len(f1))
formations = dict(f1, **f2)
print(len(formations), len(f2))
formations = dict(formations, **f3)
print(len(formations), len(f3))
formations = dict(formations, **f4)
print(len(formations), len(f4))
formations = dict(formations, **f5)
print(len(formations), len(f5))
formations = dict(formations, **f6)
print(len(formations), len(f6))
formations = dict(formations, **f7)
print(len(formations), len(f7))
formations = dict(formations, **f8)
print(len(formations), len(f8))
formations = dict(formations, **f9)
print(len(formations), len(f9))
# Out:
# 708
# 1118 410
# 1357 239
# 1537 180
# 1734 197
# 1899 165
# 2070 171
# 2392 322
# 2404 12

# %%
file1 = os.path.join(dir_path,'output/errors_' + str(0) + '_' + str(1000) + '.json') 
file2 = os.path.join(dir_path,'output/errors_' + str(1000) + '_' + str(2000) + '.json') 
file3 = os.path.join(dir_path,'output/errors_' + str(2000) + '_' + str(3000) + '.json') 
file4 = os.path.join(dir_path,'output/errors_' + str(3000) + '_' + str(4000) + '.json') 
file5 = os.path.join(dir_path,'output/errors_' + str(4000) + '_' + str(5000) + '.json') 
file6 = os.path.join(dir_path,'output/errors_' + str(5000) + '_' + str(6000) + '.json') 
file7 = os.path.join(dir_path,'output/errors_' + str(6000) + '_' + str(7000) + '.json') 
file8 = os.path.join(dir_path,'output/errors_' + str(7000) + '_' + str(8000) + '.json') 
file9 = os.path.join(dir_path,'output/errors_' + str(8000) + '_' + str(8096) + '.json') 


with open(file1, 'r') as f:
    f1 = json.load(f)

with open(file2, 'r') as f:
    f2 = json.load(f)

with open(file3, 'r') as f:
    f3 = json.load(f)

with open(file4, 'r') as f:
    f4 = json.load(f)
    
with open(file5, 'r') as f:
    f5 = json.load(f)
    
with open(file6, 'r') as f:
    f6 = json.load(f)
    
with open(file7, 'r') as f:
    f7 = json.load(f)
    
with open(file8, 'r') as f:
    f8 = json.load(f)

with open(file9, 'r') as f:
    f9 = json.load(f)
    
errors = f1 + f2 + f3 + f4 + f5 +f6 + f7 + f8 + f9 
errors
# Out:
# ["Diplôme d'ingénieur de Telecom Nancy de l'université de Lorraine (ESIAL)",
#  "Diplôme d'ingénieur de l'Ecole polytechnique universitaire de Savoie de l'université de Chambéry spécialité instrumentation, automatique, informatique (IAI) (EPU Savoie)",
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure d'ingénieurs Sud Alsace de l'université de Mulhouse spécialité mécanique (ENSISA)",
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure de génie industriel de l'Institut polytechnique de Grenoble (Ensgi)",
#  "Diplôme d'ingénieur de l'Institut catholique d'arts et métiers (ICAM)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées Centre Val de Loire spécialité génie des systèmes industriels ",
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Certificat d'études judiciaires (CEJ)",
#  "Diplôme d'élève officier de 1re classe de la marine marchande (DEO1MM)",
#  "Diplôme de l'Ecole supérieure du commerce extérieur (ESCE)",
#  "Chef de projet commercial pour l'agroalimentaire ",
#  "Responsable commercial pour l'agroalimentaire (RCAA)",
#  'Licence pro développement et protection du patrimoine culturel spécialité guide-conférencier ',
#  "Certificat d'études supérieures d'arts plastiques (CESAP)",
#  "Préparation au concours de conservateur d'Etat des bibliothèques (catégorie A) ",
#  "Préparation au concours d'entrée de l'école nationale supérieure de police ",
#  "Préparation au concours d'entrée à l'école nationale de la magistrature (ENM)",
#  'Diplôme de responsable commercial en vente ou mercatique ',
#  'error',
#  "Diplôme d'ingénieur du CESI en convention avec le CNAM spécialité bâtiment et travaux publics en partenariat avec l'ITC BTP (CESI BTP)",
#  "CPGE Classe préparatoire de lettres (1re année) avec préparation à l'option arts plastiques ",
#  "CPGE Classe préparatoire de lettres (1re année) avec préparation à l'option musique ",
#  'Responsable en gestion des ressources humaines (ISFOGEP) (ISFOGEP)',
#  'Diplôme de conservateur des bibliothèques (DCB) (DCB)',
#  "Formation d'administrateurs civils (ENA) (ENA)",
#  "Diplôme d'ingénieur de l'Ecole polytechnique de l'université Grenoble Alpes spécialité prévention des risques (Polytech)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Lyon spécialité génie industriel (INSA LYON)",
#  "Diplôme d'ingénieur de l'Institut catholique d'arts et métiers spécialité mécanique et automatique en partenariat avec l'ITII Midi-Pyrénées (ICAM)",
#  "Diplôme d'ingénieur de l'ECAM Rennes, Louis de Broglie (ECAM LB)",
#  "Diplôme d'ingénieur de l'université de technologie de Troyes spécialité génie mécanique (UTT)",
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure des technologies et industries du bois de l'université de Lorraine (ENSTIB)",
#  "Diplôme d'ingénieur du Centre universitaire des sciences et techniques de l'université Clermont Ferrand II spécialité génie civil (CUST)",
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure de céramique industrielle (ENSCI)",
#  "Diplôme d'ingénieur de l'Institut supérieur des matériaux du Mans (ISMANS)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Toulouse spécialité génie physique (INSAT)",
#  "Diplôme d'ingénieur du Centre universitaire des sciences et techniques de l'université Clermont Ferrand II spécialité génie physique (CUST)",
#  "Diplôme d'ingénieur de l'Ecole nationale du génie rural des eaux et des forêts de l'Institut des sciences et industries du vivant et de l'environnement Agro Paris Tech (IGREF)",
#  'error',
#  'Magistère Matériaux ',
#  'Magistère Mathématiques ',
#  'Magistère Mathématiques et applications ',
#  'Magistère Physique ',
#  "Magistère Juriste d'affaires interne et européen ",
#  "Magistère Juriste d'entreprise ",
#  'Magistère Droit, fiscalité et comptabilité ',
#  "Magistère Droit des techniques de l'information et de la communication ",
#  "Magistère Juriste d'affaires ",
#  'Magistère Ingénieur économiste ',
#  "Diplôme d'études universitaires de technologie (DEUTEC)",
#  'error',
#  'Négociateur immobilier ',
#  "DEUST Technicien de la mer et du littoral option gestion et aménagement de l'environnement et du littoral ",
#  'DEUST Distribution et qualité des produits alimentaires ',
#  'DEUST Formation de base aux métiers du théâtre ',
#  "DEUST Technologie de l'organisation dans les professions de santé ",
#  'Cycle préparatoire polytechnique aux INP de Bordeaux, Grenoble, Nancy et Toulouse La prépa des INP ',
#  'CPGE Classe préparatoire Biologie, chimie, physique et sciences de la Terre - Vétérinaire (Véto-BCPST), 1re année ',
#  "CPGE Classe préparatoire Mathématiques, physique et sciences de l'ingénieur (MPSI), 1re année option sciences industrielles ",
#  "CPGE Classe préparatoire Physique-chimie et sciences de l'ingénieur (PCSI) 1re année ",
#  "CPGE Classe préparatoire Physique, technologie et sciences de l'ingénieur (PTSI), 1re année ",
#  'CPGE Classe préparatoire Technologie et biologie (TB), 1re année ',
#  'CPGE Classe préparatoire Technologie, physique et chimie (TPC), 1re année ',
#  'CPGE Classe préparatoire Technologie et sciences industrielles (TSI), 1re année ',
#  'CPGE Classe préparatoire Physique-chimie (PC*), 2e année ',
#  'CPGE Classe préparatoire ATS ingénierie industrielle (ATS indus)',
#  'CPGE Classe préparatoire Technologie et biologie (TB), 2e année ',
#  'CPGE Classe préparatoire Biologie, chimie, physique et sciences de la Terre - Vétérinaire (Véto-BCPST), 2e année ',
#  'CPGE Classe préparatoire ATS biologie (ATS)',
#  'CPGE Classe préparatoire Technologie, physique et chimie (TPC), 2e année ',
#  'CPGE Classe préparatoire Technologie et sciences industrielles (TSI), 2e année ',
#  'CPGE Classe préparatoire Physique et technologie (PT), 2e année ',
#  'CPGE Classe préparatoire Physique-chimie (PC), 2e année ',
#  'CPGE Classe préparatoire Mathématiques-physique (MP*), 2e année ',
#  'CPGE Classe préparatoire Mathématiques-physique (MP), 2e année ',
#  "CPGE Classe préparatoire Physique et sciences de l'ingénieur (PSI*), 2e année ",
#  'Cycle préparatoire intégré de chimie (CPI), 2e année ',
#  'CPGE Classe préparatoire Economie et gestion option économie, droit et gestion (D1), 1re année ',
#  'CPGE Classe préparatoire Economie et gestion option économie, méthodes quantitatives et gestion (D2), 1re année ',
#  'CPGE Classe préparatoire ENS Cachan option économie, méthodes quantitatives et gestion (D2), 1 an ',
#  'CPGE Classe préparatoire ENS Rennes option économie, droit et gestion (D1), 1 an ',
#  'CPGE Classe préparatoire Economie et gestion option économie, méthodes quantitatives et gestion (D2), 2e année ',
#  'CPGE Classe préparatoire Economie et gestion option économie, droit et gestion (D1), 2e année ',
#  'CPGE Classe préparatoire Economique et commerciale option scientifique (1re année) ',
#  'CPGE Classe préparatoire Economique et commerciale option technologique (1re année) ',
#  'CPGE Classe préparatoire Economique et commerciale option technologique (2e année) ',
#  'CPGE Classe préparatoire Economique et commerciale option scientifique (2e année) ',
#  "CPGE Classe préparatoire de lettres (2e année ENS Ulm) avec préparation à la section B de l'Ecole nationale des Chartes ",
#  'CPGE Classe préparatoire de lettres (1re année) ',
#  'CPGE Classe préparatoire de lettres et sciences sociales (B/L, 1re année) ',
#  "CPGE Classe préparatoire à l'école nationale des Chartes (1re année) ",
#  "CPGE Classe préparatoire à l'école spéciale militaire de Saint Cyr (1re année) option lettres ",
#  'CPGE Classe préparatoire de lettres et sciences sociales (B/L, 2e année) ',
#  "CPGE Classe préparatoire à l'école nationale des Chartes (2e année) ",
#  "CPGE Classe préparatoire à l'école spéciale militaire de Saint Cyr (2e année) option lettres ",
#  'Formation supérieure en cinéma et audiovisuel - Prépa ciné-sup ',
#  'Formations en lettres - philosophie - sciences sociales ',
#  "Formations en langues pour les étudiants de l'université ",
#  'Responsable commercial en agro-fourniture (RCAF)',
#  'Coordonnateur en soudage et construction soudée ',
#  'error',
#  'Assistant(e) de direction(s) ',
#  "Technico-commercial de l'industrie et des services nautiques ",
#  "Coordinateur en prévention des risques et en protection de l'environnement ",
#  'error',
#  "Année de mise à niveau pour BTS à l'intention des bacs pro ",
#  'Classe de mise à niveau section de technicien supérieur hôtellerie restauration ',
#  "Année de mise à niveau pour l'entrée en première année de licence ",
#  'Année de mise à niveau littéraire ',
#  'Section métiers divers en CFA (niveau IV) ',
#  'Préparation aux écoles de la marine marchande ',
#  'Capacité en gestion (CAPG)',
#  'Technicien en pharmacie et cosmétique industrielle ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Manager en ingénierie d'affaires industrielles ",
#  'DRT Génie des systèmes industriels ',
#  'DRT Génie des matériaux ',
#  'DU Céramique industrielle et traitements de surface des matériaux ',
#  'error',
#  'Technicien supérieur en pharmacie et cosmétique industrielles (TSPCI)',
#  'Conseiller de vente en parfumerie et cosmétique ',
#  'Année de mise à niveau post bac pour entrer en DUT ',
#  'CPGE Classe préparatoire Economique et commerciale option économique (1re année) ',
#  'CPGE Classe préparatoire Economique et commerciale option économique (2e année) ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Philosophie ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Lettres modernes ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Histoire et géographie ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Musique ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Lettres classiques ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Philosophie ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Géographie ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Lettres modernes ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Histoire ',
#  "Diplôme d'ingénieur de l'Ecole supérieure d'ingénieurs en informatique et génie des télécommunications (ESIGETEL)",
#  "Diplôme d'ingénieur du CNAM spécialité construction et aménagement en partenariat avec l'IST-BTP Picardie (CNAM)",
#  "CPGE Classe préparatoire Physique-chimie et sciences de l'ingénieur (PCSI) option sciences de l'ingénieur, 1re année ",
#  "Diplôme d'ingénieur de l'École polytechnique universitaire de l'université Lyon I spécialité génie industriel (SIR)",
#  'CPGE Classe préparatoire Economique et commerciale option économique Saint Cyr (1re année) ',
#  'CPGE Classe préparatoire Economique et commerciale option économique Saint Cyr (2e année) ',
#  "CPGE Classe préparatoire Mathématiques, physique et sciences de l'ingénieur (MPSI), 1re année option informatique ",
#  'CPGE Classe préparatoire Mathématiques-physique (MP*), 2e année option informatique ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Allemand ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Anglais ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Espagnol ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Portugais ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Russe ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Allemand ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Espagnol ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Italien ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Russe ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Arabe ',
#  'error',
#  'error',
#  'Graphiste en communication multicanal ',
#  'Expert(e) en ingénierie financière (ESGF)',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Lettres classiques ',
#  "Année de mise à niveau pour BTS à l'intention des bacs généraux et technologiques ",
#  'Magistère Journalisme et communication des organisations ',
#  'CPGE Classe préparatoire Physique et technologie (PT*), 2e année ',
#  "Diplôme d'ingénieur de Télécom Physique Strasbourg de l'université de Strasbourg spécialité électronique et informatique industrielle en partenariat avec l'ITII Alsace (ITIIAlsace)",
#  "Diplôme d'ingénieur de l'Ecole polytechnique universitaire de Savoie de l'université de Chambéry spécialité mécanique-productique en partenariat avec l'ITII des Deux-Savoies (ITIISavoie)",
#  'CPGE Classe préparatoire Mathématiques-physique (MP), 2e année option informatique ',
#  "CPGE Classe préparatoire Physique et sciences de l'ingénieur (PSI), 2e année ",
#  'Conseiller en droit rural et économie agricole (IHEDREA)',
#  'Vendeur conseiller sport ',
#  'error',
#  "Chargé d'affaires Europe-Asie ",
#  "Chargé d'affaires Europe-Asie ",
#  'DEUST Animation, commercialisation des services sportifs ',
#  'CTM Boucher charcutier traiteur ',
#  'CTM Préparateur(trice) vendeur(se) option boucherie ',
#  'CTM Préparateur(trice) vendeur(se) option charcuterie-traiteur ',
#  'CTM Poëlier âtrier ',
#  'CTM Ramoneur ',
#  'Diplôme du Centre de management commercial et international (programme Global BBA) (BBA)',
#  'Diplôme préparatoire à la recherche biomédicale ',
#  'Diplôme préparatoire à la recherche biomédicale ',
#  'CPGE Classe préparatoire ENS Cachan 2e année section E langue étrangère (anglais) ',
#  'CPGE Classe préparatoire ENS Cachan 2e année section C arts et design (concours design) ',
#  'CPGE Classe préparatoire ENS Cachan 1re année section C arts et design (concours design) ',
#  'Cycle préparatoire intégré ECAM, sur le programme MPSI, PSI ',
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure d'arts et métiers spécialité génie industriel en partenariat avec Ingénieurs 2000 (ING2000)",
#  'Diplôme du programme de formation internationale en management (BSC in International Business) (BSC)',
#  'Diplôme du programme de formation internationale en management (BSC in International Business) (BSC)',
#  'CTM Fraiseur ',
#  'CTM Ajusteur monteur ',
#  'CTM Tourneur ',
#  "DPEA Design pour l'architecture (DPEA)",
#  'error',
#  'CTM Zingueur ferblantier ',
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Lyon spécialité télécommunications (INSA LYON)",
#  "Préparation à l'entrée dans les centres de formation professionnelle de notaires (CFPN)",
#  'Master ingénierie et management spécialité sport management et ingénierie - logistique événementielle et sécurité ',
#  "Diplôme ingénieur d'affaires (programme MSc ingénieur d'affaires) ",
#  "Chargé d'affaires financières et commerciales ",
#  "Diplôme de l'Institut supérieur de gestion (ISG)",
#  'Diplôme du programme grande école de Paris School of Business (PSB) (PSB)',
#  'CTM Installateur dépanneur audio vidéo électroménager ',
#  'Licence pro commerce spécialité commercialisation spécialisée produit équin ',
#  'Licence pro management des organisations spécialité management de projets dans le domaine éducatif, social ou socioculturel ',
#  'error',
#  'Licence pro bâtiment et construction spécialité maintenance et réhabilitation ',
#  'Licence pro santé spécialité instrumentation et maintenance biomédicale ',
#  'Licence pro intervention sociale spécialité médiateur socio-économique ',
#  'error',
#  'Licence pro assurance, banque, finance spécialité chargé de clientèle ',
#  "Licence pro développement et protection du patrimoine culturel spécialité métiers de l'exposition et technologies de l'information et de la communication ",
#  'error',
#  "Licence pro documentation d'entreprises et métiers de l'infodoc ",
#  'error',
#  'error',
#  'Licence pro assurance, banque, finance spécialité banque ',
#  'Licence pro génie civil et construction spécialité génie civil et construction en zone intertropicale ',
#  'error',
#  'Licence pro management des organisations spécialité gestion et pilotage de projets ',
#  'Licence pro logistique spécialité logistique hospitalière ',
#  'error',
#  'Licence pro production industrielle spécialité hydraulique industrielle ',
#  'Licence pro mécanique spécialité conception et fabrication assistée par ordinateur ',
#  'Licence pro transformations industrielles spécialité traitement des matériaux par laser ',
#  'error',
#  "Licence pro énergie et génie climatique spécialité chargé d'affaires en génie climatique ",
#  'error',
#  'Licence pro gestion de la production industrielle spécialité logistique et qualité ',
#  'error',
#  "Licence pro logistique spécialité systèmes d'information logistique - supply chain ",
#  'error',
#  'error',
#  "Licence pro gestion de la production industrielle spécialité gestion de projets d'innovation ",
#  'Licence pro logistique spécialité management de la logistique interne ',
#  'Licence pro production industrielle spécialité méthodes de conception et de production industrielles ',
#  'Licence pro production industrielle spécialité responsable de projets en conception mécanique ',
#  'Licence pro management des organisations spécialité entrepreneuriat ',
#  'error',
#  'error',
#  'error',
#  'Licence pro bâtiment et construction spécialité économie de la construction ',
#  'Licence pro commerce spécialité commerce interentreprises, commerce de gros et commerce international ',
#  'Licence pro production industrielle spécialité conception et optimisation de processus par usinage numérique ou déformation plastique ',
#  'Licence pro production industrielle spécialité ingénierie simultanée en conception numérique de produits ',
#  'Licence pro réseaux et télécommunications spécialité systèmes et réseaux de télécommunication ',
#  "Licence pro systèmes informatiques et logiciels spécialité métiers de l'administration des systèmes et des réseaux ",
#  'error',
#  'error',
#  'Licence pro réseaux et télécommunications spécialité réseaux et génie informatique ',
#  'Licence pro habillement, mode et textile spécialité mode et hautes technologies ',
#  'error',
#  "Licence pro systèmes informatiques et logiciels spécialité développement d'applications intranet-internet ",
#  'Licence pro systèmes informatiques et logiciels spécialité métiers du génie logiciel ',
#  'error',
#  'error',
#  'Licence pro automatique et informatique industrielle spécialité automatismes industriels ',
#  'error',
#  'Responsable qualité sécurité environnement (RQSE)',
#  'Licence pro management des organisations spécialité management des PME ',
#  'Licence pro production industrielle spécialité mécatronique ',
#  'DEUST Médiations citoyennes : éducation, culture, social, environnement ',
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure d'ingénieurs de Limoges de l'université de Limoges spécialité électronique et télécommunications (ENSIL)",
#  'Licence pro production industrielle spécialité robotique ',
#  'error',
#  'DEUST Intervention sociale ',
#  "DEUST Usages socio-éducatifs des technologies de l'information et de la communication (USETIC)",
#  'Licence pro hôtellerie et tourisme spécialité management hôtelier ',
#  'Licence pro génie civil et construction spécialité énergies et confort ',
#  'Diplôme ICN grande école (ICN)',
#  "Diplôme de l'Ecole de management de Strasbourg ",
#  "Diplôme de l'Ecole de management de Strasbourg ",
#  "Préparation aux concours de catégorie A de l'administration pénitentiaire ",
#  "Diplôme d'ingénieur de l'Institut polytechnique de Bordeaux - École nationale supérieure d'électronique, informatique, télécommunications, mathématique et mécanique de Bordeaux spécialité électronique (ENSEIRB)",
#  'error',
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure d'ingénieurs de Reims de l'université de Reims spécialité emballage et conditionnement (ESIReims)",
#  "Diplôme d'ingénieur de l'Ecole supérieure d'ingénieurs de recherche en matériaux de l'université de Dijon spécialité matériaux (ESIREM)",
#  "Diplôme de l'Ecole spéciale militaire de Saint-Cyr (conférant le diplôme d'ingénieur de l'ESM pour la filière sciences de l'ingénieur) (ESM)",
#  "Diplôme d'ingénieur de l'Ecole polytechnique universitaire de Lille, université Lille I spécialité génie civil (Polytech)",
#  "Diplôme d'ingénieur de l'Ecole polytechnique universitaire de Lille, université Lille I spécialité génie électrique et informatique industrielle (Polytech)",
#  "Diplôme d'ingénieur de l'Ecole polytechnique universitaire de Lille, université Lille I spécialité matériaux (Polytech)",
#  "Diplôme d'ingénieur de l'Ecole supérieure d'ingénieurs de Rennes de l'université Rennes 1 spécialité technologies de l'information (ESIR)",
#  "Diplôme d'ingénieur de l'École nationale supérieure des Mines de Douai spécialité génie industriel en partenariat avec l'IPHC inGHénia (IPHC)",
#  "Diplôme d'ingénieur de l'Institut supérieur d'informatique de modélisation et de leurs applications de l'université Clermont-Ferrand II (ISIMA)",
#  "Diplôme d'ingénieur de l'Ecole polytechnique de l'université Grenoble Alpes spécialité technologies de l'information pour la santé (Polytech)",
#  "Diplôme d'ingénieur de l'Ecole polytechnique de l'université Grenoble Alpes spécialité informatique industrielle et instrumentation (Polytech)",
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure des mines de Saint-Etienne (EMSE)",
#  "Diplôme d'ingénieur de l'université de technologie de Belfort-Montbéliard spécialité énergie (UTBM)",
#  "Diplôme d'ingénieur de l'université de technologie de Troyes spécialité génie industriel (UTT)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Lyon spécialité génie civil et urbanisme (INSA LYON)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Rennes spécialité systèmes et réseaux de communication (INSA Re)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Rennes spécialité génie civil et urbain (INSA Re)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Rennes spécialité électronique et informatique industrielle (INSA Re)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Rennes spécialité science et génie des matériaux (INSA Re)",
#  "Diplôme d'ingénieur de l'Institut national des sciences appliquées de Toulouse spécialité automatique et électronique (INSAT)",
#  'error',
#  "Certificat d'études d'arts plastiques ",
#  "Diplôme d'ingénieur de l'École polytechnique universitaire de Marseille de l'université d'Aix-Marseille spécialité matériaux (Polytech)",
#  'Chef de projet informatique et robotique (IMERIR)',
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure des ingénieurs en arts chimiques et technologiques de l'INP de Toulouse spécialité génie industriel (ENSIACET)",
#  'Licence pro systèmes informatiques et logiciels spécialité informatique répartie ',
#  "Licence pro systèmes informatiques et logiciels spécialité systèmes intra-Internet pour l'entreprise ",
#  'Licence pro management des organisations spécialité statistique décisionnelle en marketing ',
#  "Licence pro systèmes informatiques et logiciels spécialité systèmes d'information géographique ",
#  "Licence pro métiers de l'édition spécialité conception graphique multimédia ",
#  "Licence pro commerce spécialité marketing et nouvelles technologies de l'information et de la communication ",
#  'Licence pro industrie agroalimentaire, alimentation spécialité développement et recherches en arts culinaires industrialisés ',
#  'Licence pro réseaux et télécommunications spécialité intégration des systèmes embarqués en aéronautique ',
#  'Licence pro agronomie spécialité agriculture développement durable ',
#  'Licence pro automatique et informatique industrielle spécialité automatismes, réseaux et télémaintenance ',
#  'Licence pro santé spécialité réfraction analyse et prise en charge des déficits visuels ',
#  "Licence pro ressources documentaires et bases de données spécialité management de l'information ",
#  'error',
#  'error',
#  'error',
#  'Licence pro électricité et électronique spécialité électronique analogique et micro-électronique ',
#  'error',
#  'error',
#  'Licence pro production industrielle spécialité conception de produits automobiles ',
#  "Licence pro activités et techniques de communication spécialité développeur web des systèmes d'information et multimédia ",
#  'error',
#  "Licence pro systèmes informatiques et logiciels spécialité développement d'applications réparties ",
#  "Licence pro énergie et génie climatique spécialité conduite et gestion d'opérations en thermique du bâtiment ",
#  'error',
#  'error',
#  'error',
#  'error',
#  'Licence pro gestion des ressources humaines spécialité gestion des ressources humaines et paie ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Licence pro biotechnologies spécialité génie biologique, microscopie et qualité ',
#  'error',
#  'error',
#  'error',
#  'Licence pro activités sportives spécialité tourisme et loisirs sportifs ',
#  'error',
#  'Licence pro gestion des ressources humaines spécialité gestion opérationnelle et juridique des ressources humaines ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Licence pro intervention sociale spécialité conseil en écriture publique et privée, écrivain public ',
#  'error',
#  "Diplôme d'ingénieur de l'École polytechnique universitaire de Marseille de l'université d'Aix-Marseille spécialité microélectronique et télécommunications (Polytech)",
#  'Cadreur - opérateur de prise de vues, vidéo et lumière ',
#  'Opérateur du son, sonorisateur, mixeur en cinéma et audiovisuel ',
#  "Préparation au concours de conseiller d'orientation psychologue ",
#  'Licence pro génie civil et construction spécialité environnement et construction ',
#  "Préparation à l'examen d'aptitude aux fonctions de commissaire aux comptes ",
#  'Animateur musical et scénique ',
#  'error',
#  'Licence pro biotechnologies spécialité microbiologie dans les industries agroalimentaires ',
#  'Mastère spé. Management des entreprises de biotechnologies ',
#  "Licence pro techniques et activités de l'image et du son spécialité médias numériques associés aux techniques de l'image et du son ",
#  'Manager de la stratégie commerciale ',
#  "Diplôme d'ingénieur de l'Ecole supérieure angevine d'informatique et de productique spécialité sécurité et prévention des risques (ESAIP)",
#  'Formation contrôleur de la concurrence, de la consommation et de la répression des fraudes ',
#  "Formation d'inspecteur de la concurrence, de la consommation et de la répression des fraudes ",
#  'Formation de sous officier de la gendarmerie nationale ',
#  "Technicien aéronautique d'exploitation ",
#  'Préparation au concours de greffier des services judiciaires ',
#  'Préparation au concours de directeur des services de greffe judiciaires ',
#  "Préparation au concours de conseiller d'insertion et de probation ",
#  'Licence pro logistique spécialité management de la logistique ',
#  "Responsable d'affaires en immobilier ",
#  'error',
#  'error',
#  'error',
#  'error',
#  "Licence pro commerce spécialité commercial dans l'environnement européen ",
#  'Licence pro commerce spécialité développement commercial et gestion des échanges ',
#  'Licence pro développement et protection du patrimoine culturel spécialité patrimoine, tourisme, environnement ',
#  'error',
#  "Licence pro protection de l'environnement spécialité gestion durable et valorisation des écosystèmes ",
#  'error',
#  'Licence pro gestion des ressources humaines spécialité formateur en milieu professionnel ',
#  'error',
#  'Licence pro commerce spécialité technico-commercial (PME-PMI) ',
#  'error',
#  'Licence pro bâtiment et construction spécialité gestionnaire et responsable technique des sites immobiliers ',
#  'Licence pro commerce spécialité action commerciale inter-entreprise : industrie et service aux entreprises ',
#  'Licence pro maintenance des systèmes pluritechniques spécialité aéronautique ',
#  'error',
#  'Assistant de cabinet et de clinique vétérinaires ',
#  'Licence pro commerce spécialité gestion et mise en valeur des sites touristiques et culturels ',
#  'Licence pro industrie agroalimentaire, alimentation spécialité produits laitiers ',
#  'error',
#  'Licence pro activités et techniques de communication spécialité lettres, culture et nouveaux médias ',
#  'Licence pro aménagement du paysage spécialité aménagement arboré et forestier ',
#  'error',
#  'Licence pro commerce spécialité commerce en ligne ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Licence pro logistique spécialité études et projets d'organisation ",
#  'Licence pro systèmes informatiques et logiciels spécialité développeur informatique ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Licence pro réseaux et télécommunications spécialité administration et gestion des systèmes et réseaux dans les petites et moyennes organisations ',
#  'Licence pro management des organisations spécialité management des systèmes décisionnels ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Magistère Education physique et sportive ',
#  'Licence pro automatique et informatique industrielle spécialité microcircuits, cartes et applications ',
#  'Licence pro santé spécialité technologies de compensation des incapacités physiques ',
#  'Licence pro management des organisations spécialité management du logement social ',
#  'error',
#  "Licence pro management des organisations spécialité gestion des entreprises de l'économie sociale et solidaire et entrepreneuriat ",
#  'Conseiller commercial spécialisé en assurances de personnes et produits financiers ',
#  'error',
#  'Licence pro bâtiment et construction spécialité études et réalisations de projets ',
#  'Licence pro management des organisations spécialité innovations solidaires et entrepreneuriales ',
#  'Licence pro gestion de la production industrielle spécialité gestion et conception de projets industriels ',
#  'error',
#  'Licence pro réseaux et télécommunications spécialité réseaux sans fil et sécurité ',
#  'Licence pro automatique et informatique industrielle spécialité supervision des automatismes et des réseaux ',
#  'Licence pro automatique et informatique industrielle spécialité conception et supervision des systèmes automatisés ',
#  'error',
#  'Licence pro gestion de la production industrielle spécialité production et maintenance industrielles ',
#  'Licence pro commerce spécialité commercialisation de technologies ',
#  'error',
#  'error',
#  'Licence pro intervention sociale spécialité gestion de la protection sociale ',
#  'Licence pro hôtellerie et tourisme spécialité management des activités hôtelières ',
#  'Licence pro bois et ameublement spécialité construction bois ',
#  'Licence pro commerce spécialité gestionnaire import export ',
#  'error',
#  'Licence pro commerce spécialité assistant export trilingue ',
#  'Licence pro management des organisations spécialité management des entreprises agricoles ',
#  "Diplôme d'ingénieur de l'université de technologie de Troyes spécialité matériaux (UTT)",
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure des mines de Saint-Etienne spécialité génie industriel (ISTP)",
#  "Diplôme d'ingénieur de l'Institut d'ingénierie informatique de Limoges en partenariat avec l'ITII Midi-Pyrénées (3IL)",
#  'Licence pro habillement, mode et textile spécialité management et productions textiles ',
#  'Licence pro gestion des ressources humaines spécialité piloter les ressources humaines dans les PMO ',
#  'Licence pro transformations industrielles spécialité traitements de surfaces et gestion environnementale ',
#  "Licence pro intervention sociale spécialité métier de la formation individualisée et de l'insertion ",
#  "CPGE Classe préparatoire de lettres (1re année) avec préparation à l'option cinéma et audiovisuel ",
#  "CPGE Classe préparatoire de lettres (1re année) avec préparation à l'option histoire des arts ",
#  "CPGE Classe préparatoire de lettres (1re année) avec préparation à l'option théâtre ",
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Cinéma et audiovisuel ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Histoire des arts ',
#  'CPGE Classe préparatoire de lettres (2e année ENS Ulm) Théâtre ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) option Cinéma et audiovisuel ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) option Histoire des arts ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) option Théâtre ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Chinois ',
#  'error',
#  'Responsable en commerce international ',
#  'Licence pro réseaux et télécommunications spécialité administration et sécurité des réseaux ',
#  'error',
#  'Licence pro aménagement du territoire et urbanisme spécialité géomatique et développement des territoires ruraux ',
#  "Décorateur conseil d'intérieur ",
#  'error',
#  "DU Ingénierie de l'espace rural (IER) ",
#  "Diplôme d'études supérieures de réalisation (DESRA) option vidéo (DESRA)",
#  'Licence pro gestion de la production industrielle spécialité procédés en contrôle non-destructif ',
#  'Licence pro génie civil et construction spécialité construction et aménagement ',
#  'Responsable qualité hygiène sécurité environnement des entreprises viti-vinicoles ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Licence pro électricité et électronique spécialité distribution électrique et performance énergétique ',
#  'Licence pro management des organisations spécialité développement durable des territoires ruraux ',
#  'error',
#  'error',
#  'error',
#  'Licence pro automatique et informatique industrielle spécialité domotique et autonomie ',
#  "Assistant(e) de dirigeant(e) d'entreprise artisanale ",
#  "Brevet d'initiation aéronautique ",
#  'CTM Crêpier ',
#  'Caviste conseiller France commercial ',
#  "Conseiller d'élevage avicole ",
#  "Licence pro systèmes informatiques et logiciels spécialité nouvelles technologies de l'informatique ",
#  'error',
#  'error',
#  'error',
#  'Licence pro réseaux et télécommunications spécialité développement web et mobilité ',
#  'Licence pro assurance, banque, finance spécialité marché des particuliers ',
#  'error',
#  'Licence pro production industrielle spécialité innovation par la conception informatisée ',
#  'error',
#  'error',
#  'Licence pro systèmes informatiques et logiciels spécialité multimédia ',
#  'Licence pro réseaux et télécommunications spécialité commerce électronique ',
#  'Licence pro développement et protection du patrimoine culturel spécialité activités éducatives et culturelles : médiateur du patrimoine ',
#  'error',
#  'Diplôme de juriste linguiste ',
#  'Licence pro sécurité des biens et des personnes spécialité hygiène et sécurité ',
#  'Licence pro productions végétales spécialité agroressources et environnement ',
#  "Licence pro protection de l'environnement spécialité protection de l'environnement ",
#  'error',
#  'error',
#  'Diplôme arts et techniques du théâtre parcours écrivain dramaturge ',
#  'Licence pro gestion de la production industrielle spécialité techniques et technologies avancées de maintenance ',
#  'error',
#  "Diplôme de l'institut de mathématiques appliquées ",
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Licence pro techniques et activités de l'image et du son spécialité acquisition et traitement d'images ",
#  'error',
#  'Licence sciences de la vigne ',
#  'Licence pro commerce spécialité conception et distribution spécialisée jeux et jouets ',
#  'Licence pro commerce spécialité management et distribution : management de rayon de produits agricoles, horticoles ou alimentaires ',
#  'error',
#  'error',
#  'Licence pro industrie agroalimentaire, alimentation spécialité contrôles agroalimentaires et biotechnologies ',
#  'error',
#  'error',
#  'error',
#  'Licence pro travaux publics spécialité techniques routières ',
#  'Licence pro hôtellerie et tourisme spécialité LEA hôtellerie-restauration internationale ',
#  'error',
#  'Licence pro production industrielle spécialité conception et production aéronautique ',
#  'Licence pro production industrielle spécialité conception 3D avancée et calculs de structures ',
#  'Licence pro énergie et génie climatique spécialité gestionnaire énergies ',
#  'error',
#  'Licence pro management des organisations spécialité assistant de gestion et contrôle financier ',
#  'Licence pro management des organisations spécialité développement commercial des PME ',
#  'error',
#  'error',
#  "Licence pro management des organisations spécialité métiers de l'administration territoriale ",
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Licence pro maintenance des systèmes pluritechniques spécialité organisation et management des services automobiles ',
#  'Licence pro logistique spécialité logistique de distribution et logistique au service du e-commerce ',
#  'Licence pro structures métalliques spécialité métallurgie - mise en forme - soudage ',
#  'error',
#  'Licence pro maintenance des systèmes pluritechniques spécialité management des services de maintenance ',
#  'Licence pro réseaux et télécommunications spécialité intégration-administration des réseaux informatiques ',
#  'Licence pro gestion de la production industrielle spécialité management des activités supports à la production ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Licence pro logistique spécialité conception, management et commercialisation de chaîne de transport de marchandises ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'DEUST Sciences, technologies, santé bâtiment et construction spécialité bâtiment et construction ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Concepteur réalisateur multimédia ',
#  'Formation de greffier des services judiciaires ',
#  'Formation de directeur des services de greffe judiciaires ',
#  'Master rech. droit privé spécialité protection des droits fondamentaux et des libertés ',
#  'Responsable opérationnel de la distribution (programme Bachelor in Retail Management-ECAL) (ECAL)',
#  'error',
#  'error',
#  'error',
#  "Responsable en commerce et gestion pour l'agriculture et l'agroalimentaire (AGRICADRE)",
#  "Brevet de pilote professionnel d'hélicoptère ",
#  "Diplôme de l'Ecole nationale supérieure des métiers de l'image et du son (FEMIS) spécialisation distribution - exploitation ",
#  "Brevet de pilote de ligne d'hélicoptère ",
#  'error',
#  "Licence pro protection de l'environnement spécialité gestion des ressources environnementales en milieu rural. Métiers du développement durable ",
#  'Préparateur en parfum, cosmétique et aromatique ',
#  'Cycle supérieur de designer - créateur textile et mode ',
#  "Diplôme d'ingénieur du CNAM spécialité informatique en partenariat avec l'ITII Picardie ",
#  "Diplôme d'ingénieur de l'Ecole de l'air (EA)",
#  'error',
#  'error',
#  'error',
#  'Master pro management spécialité administration des entreprises ',
#  'error',
#  'Master pro management spécialité management des affaires internationales ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master sciences de la vie et de la santé spécialité physiologie, neurosciences et comportement ',
#  'error',
#  'Master pro droit public spécialité juriste des collectivités territoriales ',
#  'Master droit public spécialité droit des ressources humaines des fonctions publiques ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master pro droit privé et sciences criminelles spécialité droit notarial ',
#  'error',
#  'error',
#  'Master pro droit et management des organisations sanitaires et sociales spécialité direction, organisation, stratégie des structures sanitaires et sociales ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Master systèmes, territoires, environnements, patrimoines spécialité système d'information géographique ",
#  'error',
#  'error',
#  'Master pro psychologie spécialité neuropsychologie ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master rech. histoire spécialité histoire et archéologie comparées des sociétés médiévales (mondes chrétiens et musulmans) ',
#  'error',
#  'Master pro philosophie spécialité philosophie et pédagogie ',
#  'error',
#  'error',
#  'Master pro sociologie spécialité sciences appliquées au développement social ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master sciences du management spécialité management et administration des entreprises ',
#  'Master droit des affaires et du patrimoine privé spécialité gestion patrimoniale des conflits familiaux ',
#  'Master environnement, terre, évolution, climat spécialité archéo-géo-sciences (AGES) ',
#  'error',
#  "Master droit de l'entreprise spécialité droit social ",
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master rech. mathématiques, informatique spécialité mathématiques appliquées ',
#  'Master rech. mathématiques, informatique spécialité mathématiques fondamentales ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master maintenance aéronautique ',
#  'Master rech. chimie spécialité chimie fondamentale et appliquée ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master rech. mathématiques spécialité mathématiques fondamentales ',
#  'Master optique, image, vision spécialité optique, image, vision ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Diplôme de l'Institut d'études politiques de Toulouse ",
#  "Diplôme d'ingénieur de l'Ecole nationale supérieure des mines de Nancy de l'université de Lorraine spécialité génie mécanique (en partenariat avec l'ITII Lorraine) (GIP.InSIC)",
#  "Diplôme d'ingénieur du CNAM spécialité mécanique en partenariat avec l'ITII Picardie (ITII Picar)",
#  'Licence pro aménagement du territoire et urbanisme spécialité analyse de données géo référencées appliquées au développement local, à la distribution et aux services ',
#  'Licence pro systèmes informatiques et logiciels spécialité conception de solution décisionnelle ',
#  'Master rech. mathématiques et applications spécialité mathématiques approfondies ',
#  'error',
#  'error',
#  'Master rech. sciences de la matière spécialité chimie moléculaire et procédés propres ',
#  'error',
#  "Master mathématiques et applications spécialité mathématiques pour l'informatique graphique et les statistiques ",
#  'error',
#  'error',
#  "Master pro sciences chimiques pour le développement durable spécialité qualité, environnement et sécurité dans l'industrie et les services ",
#  'Master sciences de la matière spécialité nanotechnologies et nanobiosciences ',
#  'Master sciences de la matière spécialité contrôle et durabilité des matériaux ',
#  'error',
#  'error',
#  "Master sciences de l'éducation et de la formation spécialité recherche en éducation formation et pratiques sociales ",
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master pro information, communication, culture spécialité ingénierie des métiers de la culture ',
#  'CPGE Classe préparatoire de lettres et sciences humaines (2e année ENS Lyon) Anglais ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Master rech. sciences historiques spécialité histoire de l'art ",
#  'Master création artistique spécialité arts plastiques thérapie ',
#  'error',
#  'Master rech. sciences économiques spécialité analyses et politiques économiques, recherche ',
#  "Master pro sciences économiques spécialité management et évaluation des organisations de santé et d'emploi-formation ",
#  'Master sciences économiques spécialité économie et gouvernance des territoires ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Master pro management du social et de la santé spécialité gestion des politiques sociales et de l'économie solidaire ",
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master rech. philosophie spécialité imaginaire et rationalité ',
#  'Master pro philosophie spécialité philosophie et monde professionnel ',
#  'Master pro cultures et sociétés, XVI-XXIe siècles spécialité archives des XXe et XXIe siècles européens : du papier au numérique ',
#  'Master géographie, aménagement, environnement spécialité transports, mobilités, environnement, climat ',
#  'Master rech. cultures et sociétés, XVI-XXIe siècles spécialité cultures et sociétés, XVIe-XXIe siècles ',
#  'Master pro psychologie spécialité psychopathologie psychanalytique ',
#  'Master pro psychologie spécialité psychologie du travail : management des relations humaines et des communications ',
#  'Master psychologie spécialité psychologie clinique du développement, des apprentissages et du vieillissement ',
#  'Master psychologie spécialité ingénierie cognitive des apprentissages en technologies pour la formation professionnelle ',
#  'Master psychologie spécialité psychopathologie clinique, psychologie médicale et psychothérapie ',
#  'Master rech. psychologie spécialité psychologie sociale et sciences du sport et des loisirs ',
#  'Master pro éducation et formation spécialité pilotage et évaluation dans les systèmes éducatifs ',
#  'Master pro éducation et formation spécialité conseiller, consultant, responsable de formation ',
#  'Master rech. finance internationale et économie de la mondialisation spécialité économie et finance internationale ',
#  'Master rech. organisation des firmes et des marchés, connaissance et innovation spécialité économie, cognition et innovation ',
#  "Master pro organisation des firmes et des marchés, connaissance et innovation spécialité économie et management de l'organisation industrielle ",
#  'Master rech. langues et cultures étrangères : aire culturelle asiatique spécialité recherche en sinologie ',
#  'Master rech. langues et cultures étrangères : aire culturelle arabe, musulmane et hamito-sémitique spécialité recherche ',
#  'Master rech. langues et cultures étrangères : aire culturelle anglophone spécialité recherche ',
#  'Master rech. langues et cultures étrangères : aire interculturelle franco-allemande spécialité recherche, aire interculturelle franco-allemande ',
#  'Master pro langues et cultures étrangères : aire culturelle arabe, musulmane et hamito-sémitique spécialité tourisme, langues et patrimoine ',
#  'Master pro langues et cultures étrangères : aire culturelle romane spécialité tourisme, langues et patrimoine ',
#  'Master rech. langues et cultures étrangères : aire culturelle romane spécialité recherche ',
#  'Master pro langues étrangères appliquées spécialité langues étrangères appliquées aux affaires internationales ',
#  'Master pro éducation et formation spécialité responsable de formation et intervenants en organisation (consultants et coachs) ',
#  'Master rech. droit économique et des affaires spécialité droit économique et des affaires ',
#  'Master pro droit économique et des affaires spécialité juriste du sport ',
#  'Master pro international business / affaires internationales spécialité affaires et management international ',
#  'Master pro management spécialité management de projets innovants ',
#  'Master pro management spécialité management du sport ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Licence pro assurance, banque, finance spécialité les métiers de l'immobilier dans la construction et la gestion immobilière ",
#  'Licence pro industries chimiques et pharmaceutiques spécialité management des industries de la cosmétique et de la chimie fine ',
#  'Licence pro santé spécialité optique professionnelle ',
#  'Master science politique spécialité enquêtes, études politiques, opinions ',
#  'error',
#  'error',
#  'Master rech. informatique spécialité intelligence artificielle et décision ',
#  'Master rech. informatique spécialité multimédia and data management ',
#  'Master rech. informatique spécialité informatique fondamentale ',
#  'error',
#  'error',
#  'Master rech. développement économique spécialité macroéconomie financière et développement ',
#  'Master pro sciences du management spécialité qualité et contrôle interne ',
#  'Master management et commerce international spécialité commercialisation internationale des vins ',
#  'Master pro développement territorial durable spécialité management du tourisme durable des loisirs et sports de nature ',
#  'Master pro sciences du management spécialité affaires internationales sud-méditerranéennes ',
#  'error',
#  'Licence pro productions végétales spécialité pratiques agricoles, aménagement rural, techniques alternatives, gestion écologique des ressources ',
#  'Master physique-chimie spécialité nanosciences, optique, atmosphère ',
#  'Master écologie biodiversité spécialité maladies transmissibles : dynamique et environnement ',
#  'Licence pro ressources documentaires et bases de données spécialité traitement et gestion des archives et des bibliothèques ',
#  'Master langues, cultures étrangères et régionales spécialité breton et celtique ',
#  'Master langues, cultures étrangères et régionales spécialité études germaniques ',
#  'Master langues, cultures étrangères et régionales spécialité russe ',
#  'Master langues, cultures étrangères et régionales spécialité les Amériques ',
#  'Master pro linguistique et didactique des langues spécialité anglais langue étrangère (ALE/LANSAD) ',
#  'Master pro langues étrangères appliquées spécialité management et marketing international ',
#  'Master pro langues étrangères appliquées spécialité métiers de la traduction-localisation et de la communication multilingue et multimédia ',
#  "Master pro sciences de l'éducation spécialité stratégie et ingénierie en formation d'adultes ",
#  "Master pro sciences de l'éducation spécialité technologies de l'éducation et de la formation ",
#  'Master pro droit privé spécialité carrières judiciaires ',
#  'Master rech. lettres et langues européennes et internationales spécialité littératures et langages ',
#  "Master pro lettres et langues européennes et internationales spécialité responsable du développement à l'international ",
#  "Master pro droit des affaires spécialité juriste d'affaires internationales ",
#  'Master pro droit des affaires spécialité droit et gestion du patrimoine ',
#  'Master pro lettres et langues spécialité littérature pour la jeunesse ',
#  'Master langues et langage spécialité didactique des langues et des cultures ',
#  'Master pro langues étrangères appliquées spécialité logistique internationale ',
#  "Master pro sciences de l'éducation et de la formation spécialité formation européenne des enseignants ",
#  "Master sciences de l'éducation et de la formation spécialité métiers, pratiques et recherches en éducation et formation ",
#  'error',
#  'error',
#  'error',
#  'error',
#  'Master pro droit public spécialité droit, santé, éthique ',
#  'Master pro droit public spécialité conseil et contentieux des personnes publiques ',
#  'Master pro biologie, agronomie, santé spécialité biologie-gestion ',
#  'Master métiers du livre et humanités numériques spécialité édition, lexicographie, documentation numérique ',
#  "Master pro information et communication spécialité métiers de l'information-communication organisationnelle ",
#  'Master pro information et communication spécialité études et projets spécifiques en information et communication ',
#  'Master droit privé spécialité droit civil et notarial ',
#  'Licence pro commerce spécialité information stratégique et action sur les marchés ',
#  'Master rech. langues et langage spécialité sciences du langage ',
#  'Master rech. lettres et philosophie spécialité lettres classiques ',
#  'error',
#  "Master français langue étrangère spécialité ingénierie de l'enseignement et de la formation des formateurs en FLE / FLS ",
#  'Master rech. langues et cultures étrangères spécialité études anglophones ',
#  'error',
#  'Master langues et cultures étrangères spécialité études anglophones ',
#  'Master rech. langues et cultures étrangères spécialité études italiennes ',
#  'Master langues et cultures étrangères spécialité études japonaises ',
#  'Licence pro management des organisations spécialité management des entreprises culturelles ',
#  'Licence pro management des organisations spécialité management des établissements équestres ',
#  'Master pro psychologie spécialité évaluations cognitives et cliniques ',
#  'Licence pro assurance, banque, finance spécialité métiers de la retraite et de la prévoyance ',
#  "Master pro psychologie spécialité psychologie de l'enfant et de l'adolescent : développements, interaction et dysfonctionnements ",
#  'Master pro administration spécialité mondes contemporains : carrières publiques ',
#  'Master sociologie spécialité recherche et métiers du diagnostic sociologique ',
#  "Master pro sociologie spécialité métiers du développement territorial et de l'économie sociale et solidaire ",
#  'Master rech. histoire spécialité recherche ',
#  'Master pro histoire spécialité valorisation du patrimoine culturel et développement local ',
#  'Master géographie et aménagement spécialité politiques territoriales de développement durable ',
#  'error',
#  'error',
#  'error',
#  'Licence pro management des organisations spécialité management de la relation client Europe ',
#  'Licence pro commerce spécialité cadre commercial du nautisme ',
#  'Master lettres et langues spécialité langues, littératures, traduction et cultures ',
#  'Master rech. langues étrangères (allemand, anglais, espagnol, italien) spécialité études germaniques ',
#  'Master rech. droit public spécialité droit public approfondi ',
#  'Master langues, littératures et cultures étrangères spécialité études anglophones ',
#  'Master droit privé et sciences criminelles spécialité théorie du droit ',
#  'Master pro droit public spécialité droit et pratique des contentieux publics ',
#  'Master pro droit public spécialité carrières administratives ',
#  "Master droit international et européen spécialité droit international et européen de l'environnement ",
#  "Master banque et affaires internationales spécialité financement d'entreprises et d'affaires internationales ",
#  "Master droit privé et sciences criminelles spécialité procédures et voie d'exécution ",
#  'Master rech. droit privé et sciences criminelles spécialité sciences criminelles ',
#  'Master pro droit privé et sciences criminelles spécialité métiers de la défense : conseil et formation juridique des forces armées ',
#  "Master pro droit privé et sciences criminelles spécialité lutte contre l'insécurité ",
#  "Master pro droit privé et sciences criminelles spécialité métiers de la police et de l'administration pénitentiaire ",
#  'Master pro droit privé et sciences criminelles spécialité lutte contre la criminalité financière et organisée ',
#  'Master droit patrimonial, immobilier et notarial spécialité droit immobilier privé et public ',
#  'Master rech. droit patrimonial, immobilier et notarial spécialité droit de la responsabilité et des assurances ',
#  'Master pro droit patrimonial, immobilier et notarial spécialité carrière notariale ',
#  'Master pro droit patrimonial, immobilier et notarial spécialité fiscalité personnelle et du patrimoine ',
#  'Master pro commerce, décision, gestion spécialité compétences complémentaires en informatique ',
#  'Master droit international et européen spécialité droit international public ',
#  "Master droit international et européen spécialité droit de l'Union européenne ",
#  "Master pro droit patrimonial, immobilier et notarial spécialité droit de la protection de l'environnement - territoires méditerranéens ",
#  'Master droit international et européen spécialité action et droits humanitaires ',
#  'Master droit spécialité droit des contrats publics et privés ',
#  'Master rech. droit international et européen spécialité droit international privé ',
#  'Master pro droit et management de la culture et des médias spécialité journalisme juridique ',
#  'Master pro droit et management de la culture et des médias spécialité droit et activités artistiques ',
#  'Master droit public spécialité contrats publics et droit public des affaires ',
#  'Master rech. droit de la santé spécialité droit privé et public de la santé ',
#  'Master pro droit public spécialité droit et management publics des collectivités territoriales ',
#  'Master pro droit des affaires spécialité droit comparé appliqué ',
#  'Master rech. droit des affaires spécialité droit économique ',
#  'Master rech. droit des affaires spécialité droit social ',
#  "Master pro droit des affaires spécialité droit et fiscalité de l'entreprise ",
#  'Master informatique spécialité apprentissage et traitement automatique de la langue ',
#  'Master pro droit des affaires spécialité droit des affaires internationales ',
#  'Master pro droit des affaires spécialité ingénierie des sociétés ',
#  'Master pro droit des affaires spécialité droit du sport ',
#  'Master pro droit des affaires spécialité transports maritimes ',
#  'Master pro droit des affaires spécialité droit et management du transport aérien ',
#  'Master pro droit des affaires spécialité transports terrestres ',
#  'Master pro droit des affaires spécialité droit vitivinicole et des produits de qualité ',
#  'error',
#  'error',
#  'error',
#  'Master rech. langues et cultures étrangères spécialité études germaniques ',
#  'error',
#  'Master pro informatique spécialité bio-informatique ',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  "Master pro droit privé spécialité droit de l'exécution des peines et droits de l'Homme ",
#  'error',
#  'Master fiance, contrôle, comptabilité spécialité ingénierie de la finance de marché ',
#  ...]

# %%
# Boucle pour récupérer les formations
# La liste "errors" contient les formations avec des liens inexistants

formations = {}
errors = []
for row in formations_links.iterrows():
    name = row[1]["libellé principal"]
    link = row[1]["lien site onisep.fr"]
    formation_content = parse_formation_page(link)
    if formation_content is not 'error':
        formations[name] = formation_content
    else:
        errors.append(name)

# %%
# Copie du dictionnaire au format JSON
with open(formations_output_path, 'w') as f:
    json.dump(formations, f, indent=4)

# Copie du dictionnaire au format JSON
with open(errors_output_path, 'w') as f:
    json.dump(errors, f, indent=4)
