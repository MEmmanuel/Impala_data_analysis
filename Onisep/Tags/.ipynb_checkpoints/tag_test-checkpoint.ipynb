# %%
import os
import json
import numpy as np
import math
import pandas as pd

# %%
# Chemins utiles
dir_path = os.getcwd()
# Tags file
tags_path = os.path.join(dir_path, 'tags_assoc_10oct.xlsx')
# All_tags file
all_tags_path = os.path.join(dir_path, 'tags_assoc_10oct(1).xlsx')

# %%
metiers_tags = pd.read_excel(tags_path, sheetname=1, header=0)
metiers_tags.head()
all_tags = pd.read_excel(all_tags_path, sheetname=1, header=0,)
# Out:
#                                                  job          tag  \
# 0  développeur rural / développeuse rurale humani...    populaire
# 1  développeur rural / développeuse rurale humani...  vocabulaire
# 2  développeur rural / développeuse rurale humani...    exterieur
# 3  développeur rural / développeuse rurale humani...          LEA
# 4  développeur rural / développeuse rurale humani...       bouger
#
#    delete_assoc  delete_tag  add_tag
# 0           0.0         1.0      NaN
# 1           0.0         1.0      NaN
# 2           0.0         1.0      NaN
# 3           0.0         1.0      NaN
# 4           1.0         0.0      NaN

# %%
jobs_list = np.unique(metiers_tags["job"]).tolist()
jobs_list[0:10]
# Out:
# ['directeur / directrice artistique',
#  "directeur / directrice d'accueil collectif de mineurs (ACM)",
#  "directeur / directrice d'agence bancaire",
#  "directeur / directrice d'hôpital",
#  "directeur / directrice d'hôtel",
#  "directeur / directrice d'office de tourisme",
#  'directeur / directrice de centre pénitentiaire',
#  'directeur / directrice de création',
#  'directeur / directrice de golf',
#  'directeur / directrice de la photographie']

# %%
tags_sample = np.unique(metiers_tags["tag"]).tolist()
print("Nombre de tags dans le sample", len(tags_sample))
all_tags = pd.read_excel(all_tags_path, sheetname=1, header=0,)
# Out:
# Nombre de tags dans le sample 653

# %%
df_mt = {}
tags_list = []
for job in jobs_list:
    df_mt[job] = []

for row in metiers_tags.itertuples():
    job = row[1]
    tag = row[2]
    if row[4]==0:
        df_mt[job].append(tag)
        if tag not in tags_list:
            tags_list.append(tag)

# %%
tags_list
# Out:
# ['bouger',
#  'rencontrer',
#  'sociable',
#  'voyager',
#  'étranger',
#  'langue',
#  'anglais',
#  'agronomie',
#  'rencontre',
#  'agroalimentaire',
#  'voyage',
#  "travailler à l'extérieur",
#  'humanitaire',
#  'nature',
#  'biologie',
#  'animaux',
#  'campagne',
#  'expatriation',
#  'durable',
#  'éducation',
#  'développement durable',
#  'agriculture',
#  'rural',
#  'humain',
#  'repas',
#  'conseiller',
#  'psychologie',
#  'thérapeutique',
#  'alimentaire',
#  'santé',
#  'paramédical',
#  'organiser',
#  'publicité',
#  'contact',
#  'administration',
#  'management',
#  'responsabilité',
#  'gestion',
#  'dirigeant',
#  'communication',
#  'manager',
#  'créativité',
#  'directeur',
#  'art',
#  'utile',
#  'école',
#  'jeunes',
#  'pédagogie',
#  'social',
#  'jeunesse',
#  'enseigner',
#  'sociologie',
#  'mineur',
#  'animer',
#  'enfants',
#  'chiffres',
#  'vente',
#  'affaires',
#  'commerce',
#  'business',
#  'chiffre',
#  'négociation',
#  'diriger',
#  'gérer',
#  'finance',
#  'banque',
#  'audit',
#  'chef',
#  'vendre',
#  'négocier',
#  'règle',
#  'justice',
#  'sécurité',
#  'sûreté',
#  'leader',
#  'créatif',
#  'marketing',
#  'communiquer',
#  'création',
#  'créer',
#  'pub',
#  'artiste',
#  'décoration',
#  'graphisme',
#  'design',
#  'tourisme',
#  'loisirs',
#  'superviser',
#  'image',
#  'magazine',
#  'multimedia',
#  'caméra',
#  'cinéma',
#  'lumière',
#  'spectacle',
#  'audiovisuel',
#  'magasin',
#  'distribuer',
#  'hôpital',
#  'médecine',
#  'hôtellerie',
#  'administrer',
#  'territoire',
#  'région',
#  'guider',
#  'informer',
#  'culture',
#  'information',
#  'histoire',
#  'expliquer',
#  'média',
#  'media',
#  'traiter',
#  'archives',
#  'livre',
#  'documenter',
#  'musée',
#  'high-tech',
#  'immobilier',
#  'technologie',
#  'connecté',
#  'robotique',
#  'ordinateur',
#  'informatique',
#  'réseau',
#  'télécommunications',
#  'domotique',
#  'ssii',
#  'maison',
#  'télécoms',
#  'télécommunication',
#  'bâtiment',
#  'exterieur',
#  'protection des animaux',
#  'cheval',
#  'animal',
#  'tournage',
#  'régie',
#  'scène',
#  'décor',
#  'théâtre',
#  'éclairer',
#  'btp',
#  'écologie',
#  'énergies renouvelables',
#  'économie',
#  'améliorer',
#  'climat',
#  'énergie',
#  'planète',
#  'edf',
#  'thermique',
#  'environnement',
#  'climatique',
#  'compter',
#  'logique',
#  'science',
#  'programmation',
#  'centrale nucléaire',
#  'politique',
#  'statistiques',
#  'mathématiques',
#  'simulateur',
#  'simulation',
#  'maths',
#  'construction',
#  'urbanisme',
#  'architecte',
#  'travaux',
#  'budget',
#  'chantier',
#  'construire',
#  'architecture',
#  'lire',
#  'rédiger',
#  'lecture',
#  'écriture',
#  'rédaction',
#  'littéraire',
#  'écrire',
#  'édition',
#  'multimédia',
#  'presse',
#  'familial',
#  'famille',
#  'discuter',
#  'juridique',
#  'prof',
#  'sportif',
#  'sport',
#  'piscine',
#  'handicapé',
#  'paysage',
#  'travailler dehors',
#  'entretien',
#  'végétal',
#  'arbre',
#  'bricoler',
#  'artisan',
#  'restauration',
#  'restaurateur',
#  'peinture',
#  'conserver',
#  'toile',
#  'patrimoine',
#  'artisanat',
#  'bricolage',
#  'déduire',
#  'défendre',
#  'comprendre',
#  'droit',
#  'enquêter',
#  'déduction',
#  'secret',
#  'vérifier',
#  'confidentiel',
#  'physique-chimie',
#  'professeur',
#  'chercheur',
#  'docteur',
#  'master',
#  'biotechnologie',
#  'laboratoire',
#  'conférence',
#  'enseignant-chercheur',
#  'thèse',
#  'expérimenter',
#  'chimie',
#  'pharmacie',
#  'médicament',
#  'enseignement',
#  'recherche',
#  'université',
#  'dessin',
#  'dessiner',
#  'archéologie',
#  'transport',
#  'conduire',
#  'automobile',
#  'examen',
#  'routier',
#  'voiture',
#  'route',
#  'véhicule',
#  'sensibiliser',
#  'lycée',
#  'fonctionnaire',
#  'sociabilité',
#  'traitement',
#  'confiance',
#  'scolaire',
#  'classe',
#  'difficulté',
#  'équestre',
#  'élevage',
#  'consultant',
#  'handicap',
#  'conseil']

# %%
tags = ['presse','livre']

df_score = pd.DataFrame(columns = ['métier','score'])

j = 0
for job in df_mt:
    df_score.loc[j,'métier'] = job
    df_score.loc[j,'score'] = 0
    for tag in tags:
        if tag in df_mt[job]:
            df_score.loc[j,'score'] = df_score.loc[j,'score']+1
    j+=1

df_score.head()
# Out:
#                                            métier score
# 0          formateur / formatrice en informatique     0
# 1        gardien / gardienne de police municipale     0
# 2                              éditeur / éditrice     2
# 3   enseignant-chercheur / enseignante-chercheuse     0
# 4  directeur / directrice de centre pénitentiaire     0

# %%
df_score.sort_values(by="score",ascending=False)
# Out:
#                                                métier score
# 2                                  éditeur / éditrice     2
# 9                                      documentaliste     1
# 50                               écrivain / écrivaine     1
# 44  éducateur / éducatrice de la protection judici...     0
# 49                               façadier / façadière     0
# 48                    facteur/ factrice d'instruments     0
# 47                                        étanchéiste     0
# 46                     enseignant / enseignante d'art     0
# 45  enseignant / enseignante de la conduite automo...     0
# 0              formateur / formatrice en informatique     0
# 52                     dresseur / dresseuse d'animaux     0
# 43                                          fleuriste     0
# 42                                 facteur / factrice     0
# 41  éducateur technique spécialisé / éducatrice te...     0
# 40  directeur / directrice de magasin à grande sur...     0
# 39                     employé / employée de pressing     0
# 38                entraîneur / entraîneuse de chevaux     0
# 51                     ferronnier / ferronnière d'art     0
# 54            éducateur sportif / éducatrice sportive     0
# 53               expert-comptable / experte-comptable     0
# 36                        expert / experte automobile     0
# 55                                     ergothérapeute     0
# 56                                           ergonome     0
# 57  électromécanicien / électromécanicienne en rem...     0
# 58                        diététicien / diététicienne     0
# 59                                         ethnologue     0
# 60                                         étalagiste     0
# 61           économètre statisticien / statisticienne     0
# 62                   employé / employée de restaurant     0
# 63           directeur / directrice d'agence bancaire     0
# ..                                                ...   ...
# 4      directeur / directrice de centre pénitentiaire     0
# 5                           domoticien / domoticienne     0
# 6                                      garde à cheval     0
# 7                      expert / experte en assurances     0
# 8                   directeur / directrice artistique     0
# 10  éducateur sportif / éducatrice sportive des ac...     0
# 11                 directeur / directrice de création     0
# 12                      expert /experte bilan carbone     0
# 13      éducateur spécialisé / éducatrice spécialisée     0
# 14                     directeur / directrice d'hôtel     0
# 15             expert immobilier / experte immobilier     0
# 16         électronicien / électronicienne automobile     0
# 17  esthéticien-cosméticien / esthéticienne-cosmét...     0
# 19   façonnier / façonnière des industries graphiques     0
# 1            gardien / gardienne de police municipale     0
# 20                                         fiscaliste     0
# 21                                 éleveur / éleveuse     0
# 22            électromécanicien / électromécanicienne     0
# 23          directeur / directrice de la photographie     0
# 24                      économiste de la construction     0
# 25                                     garçon de café     0
# 26    enseignant spécialisé / enseignante spécialisée     0
# 27                   formateur / formatrice d'adultes     0
# 28  développeur rural / développeuse rurale humani...     0
# 29          expert / experte en sécurité informatique     0
# 30        directeur / directrice d'office de tourisme     0
# 31                         formulateur / formulatrice     0
# 32  directeur / directrice d'accueil collectif de ...     0
# 33                                       éclairagiste     0
# 68                enquêteur privé / enquêtrice privée     0
#
# [69 rows x 2 columns]
